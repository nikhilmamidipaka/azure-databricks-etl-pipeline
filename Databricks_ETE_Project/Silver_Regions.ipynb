# %%
df = spark.read.table("databricks_catalog.bronze.regions")
df.display()

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta").mode("overwrite")\
    .save("abfss://silver@stgdatabricksete14.dfs.core.windows.net/regions")

# %%
df = spark.read.format('delta').load("abfss://silver@stgdatabricksete14.dfs.core.windows.net/regions")
df.display()

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_catalog.silver.regions_silver
using DELTA
LOCATION "abfss://silver@stgdatabricksete14.dfs.core.windows.net/regions"
